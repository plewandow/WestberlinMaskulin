# %%
print("Programmieren ist kein Vergnügen, sondern Hass")
# Out:
# Programmieren ist kein Vergnügen, sondern Hass

# %%
a = int(input("Eine Zahl, bitte"))
print("Die Zahl ist ", a, "!")
# Out:
# Eine Zahl, bitte 4
# Die Zahl ist  4 !
